# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import cv2
import os
import matplotlib.image as mpimg
import random
from sklearn import preprocessing
import tensorflow.keras as keras
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

# %%
# !pip install -U pandas
# Out:
# Requirement already satisfied: pandas in ./anaconda3/lib/python3.11/site-packages (2.2.0)
# Collecting pandas
#   Downloading pandas-2.2.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2,>=1.23.2 in ./anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in ./anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in ./anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.1-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 9.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.0
#     Uninstalling pandas-2.2.0:
#       Successfully uninstalled pandas-2.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.5 which is incompatible.
# Successfully installed pandas-2.2.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import cv2
import os
import matplotlib.image as mpimg
import random
from sklearn import preprocessing
import tensorflow.keras as keras
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

# %%
SIZE = 256
SEED_TRAINING = 121
SEED_TESTING = 197
SEED_VALIDATION = 164
CHANNELS = 3
n_classes = 3
EPOCHS = 50
BATCH_SIZE = 16
input_shape = (SIZE, SIZE, CHANNELS)

# %%
train_datagen = ImageDataGenerator(
        rescale = 1./255,
        rotation_range = 30,
        shear_range = 0.2,
        zoom_range = 0.2,
        width_shift_range=0.05,
        height_shift_range=0.05,
        horizontal_flip = True,
        fill_mode = 'nearest')

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
train_generator = train_datagen.flow_from_directory(
        directory = '/Users/ankitkumarnath/Documents/project/potato',  # this is the input directory
        target_size = (256, 256),  # all images will be resized to 64x64
        batch_size = BATCH_SIZE,
        class_mode = 'categorical',
        color_mode="rgb")
validation_generator = validation_datagen.flow_from_directory(
        '/Users/ankitkumarnath/Documents/project/potato',
        target_size = (256, 256),
        batch_size = BATCH_SIZE,
        class_mode='categorical',
        color_mode="rgb")
test_generator = test_datagen.flow_from_directory(
        '/Users/ankitkumarnath/Documents/project/potato/',
        target_size = (256, 256),
        batch_size = BATCH_SIZE,
        class_mode = 'categorical',
        color_mode = "rgb"
)
# Out:
# Found 2152 images belonging to 3 classes.
# Found 2152 images belonging to 3 classes.
# Found 2152 images belonging to 3 classes.

# %%
model = keras.models.Sequential([
        keras.layers.Conv2D(32, (3,3), activation = 'relu', input_shape = input_shape),
        keras.layers.MaxPooling2D((2, 2)),
        keras.layers.Dropout(0.5),
        keras.layers.Conv2D(64, (3,3), activation = 'relu', padding = 'same'),
        keras.layers.MaxPooling2D((2,2)),
        keras.layers.Dropout(0.5),
        keras.layers.Conv2D(64, (3,3), activation = 'relu', padding = 'same'),
        keras.layers.MaxPooling2D((2,2)),
        keras.layers.Conv2D(64, (3,3), activation = 'relu', padding = 'same'),
        keras.layers.MaxPooling2D((2,2)),
        keras.layers.Conv2D(64, (3,3), activation = 'relu', padding = 'same'),
        keras.layers.MaxPooling2D((2,2)),
        keras.layers.Conv2D(64, (3,3), activation = 'relu', padding = 'same'),
        keras.layers.MaxPooling2D((2,2)),
        keras.layers.Flatten(),
        keras.layers.Dense(32, activation ='relu'),
        keras.layers.Dense(n_classes, activation='softmax')
    ])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 32)      0
#  D)
#
#  dropout (Dropout)           (None, 127, 127, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 127, 127, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 63, 63, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 63, 63, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 63, 63, 64)        36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 31, 31, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 31, 31, 64)        36928
#
#  max_pooling2d_3 (MaxPoolin  (None, 15, 15, 64)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 15, 15, 64)        36928
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 64)          36928
#
#  max_pooling2d_5 (MaxPoolin  (None, 3, 3, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 32)                18464
#
#  dense_1 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 185667 (725.26 KB)
# Trainable params: 185667 (725.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.CategoricalCrossentropy(),
    metrics  = ['accuracy']
    )

# %%
history = model.fit_generator(
        train_generator,
        steps_per_epoch = train_generator.n // train_generator.batch_size,    #The 2 slashes division return rounded integer
        epochs = EPOCHS,
        validation_data = validation_generator,
        validation_steps = validation_generator.n // validation_generator.batch_size
        )
# Out:
# /var/folders/zm/mpwd_g3j7vl1_27mwwvx0lm00000gn/T/ipykernel_35860/2547534726.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/50
# 134/134 [==============================] - 57s 425ms/step - loss: 0.7739 - accuracy: 0.6428 - val_loss: 0.6063 - val_accuracy: 0.7980
# Epoch 2/50
# 134/134 [==============================] - 60s 446ms/step - loss: 0.4232 - accuracy: 0.8315 - val_loss: 0.4645 - val_accuracy: 0.8517
# Epoch 3/50
# 134/134 [==============================] - 61s 456ms/step - loss: 0.2940 - accuracy: 0.8844 - val_loss: 0.2063 - val_accuracy: 0.9226
# Epoch 4/50
# 134/134 [==============================] - 62s 460ms/step - loss: 0.2833 - accuracy: 0.8895 - val_loss: 0.3793 - val_accuracy: 0.8806
# Epoch 5/50
# 134/134 [==============================] - 63s 468ms/step - loss: 0.2596 - accuracy: 0.8970 - val_loss: 0.1974 - val_accuracy: 0.9310
# Epoch 6/50
# 134/134 [==============================] - 65s 485ms/step - loss: 0.2028 - accuracy: 0.9176 - val_loss: 0.2010 - val_accuracy: 0.9282
# Epoch 7/50
# 134/134 [==============================] - 67s 497ms/step - loss: 0.1977 - accuracy: 0.9176 - val_loss: 0.3258 - val_accuracy: 0.8699
# Epoch 8/50
# 134/134 [==============================] - 63s 472ms/step - loss: 0.1941 - accuracy: 0.9251 - val_loss: 0.1225 - val_accuracy: 0.9566
# Epoch 9/50
# 134/134 [==============================] - 64s 478ms/step - loss: 0.1706 - accuracy: 0.9349 - val_loss: 0.1203 - val_accuracy: 0.9580
# Epoch 10/50
# 134/134 [==============================] - 65s 484ms/step - loss: 0.1591 - accuracy: 0.9340 - val_loss: 0.1356 - val_accuracy: 0.9473
# Epoch 11/50
# 134/134 [==============================] - 64s 480ms/step - loss: 0.1376 - accuracy: 0.9443 - val_loss: 0.1579 - val_accuracy: 0.9417
# Epoch 12/50
# Epoch 33/50
# 134/134 [==============================] - 66s 496ms/step - loss: 0.0692 - accuracy: 0.9733 - val_loss: 0.1313 - val_accuracy: 0.9459
# Epoch 34/50
# 134/134 [==============================] - 66s 494ms/step - loss: 0.0361 - accuracy: 0.9878 - val_loss: 0.0633 - val_accuracy: 0.9785
# Epoch 35/50
# 134/134 [==============================] - 66s 490ms/step - loss: 0.0271 - accuracy: 0.9892 - val_loss: 0.0398 - val_accuracy: 0.9837
# Epoch 36/50
# 134/134 [==============================] - 65s 486ms/step - loss: 0.0531 - accuracy: 0.9813 - val_loss: 0.0181 - val_accuracy: 0.9963
# Epoch 37/50
# 134/134 [==============================] - 65s 485ms/step - loss: 0.0288 - accuracy: 0.9892 - val_loss: 0.1636 - val_accuracy: 0.9361
# Epoch 38/50
# 134/134 [==============================] - 64s 481ms/step - loss: 0.0254 - accuracy: 0.9920 - val_loss: 0.0135 - val_accuracy: 0.9967
# Epoch 39/50
# 134/134 [==============================] - 66s 491ms/step - loss: 0.0175 - accuracy: 0.9944 - val_loss: 0.0214 - val_accuracy: 0.9925
# Epoch 40/50
# 134/134 [==============================] - 64s 480ms/step - loss: 0.0398 - accuracy: 0.9874 - val_loss: 0.0213 - val_accuracy: 0.9930
# Epoch 41/50
# 134/134 [==============================] - 64s 477ms/step - loss: 0.0260 - accuracy: 0.9930 - val_loss: 0.0150 - val_accuracy: 0.9939
# Epoch 42/50
# 134/134 [==============================] - 65s 484ms/step - loss: 0.0381 - accuracy: 0.9855 - val_loss: 0.0208 - val_accuracy: 0.9921
# Epoch 43/50
# 134/134 [==============================] - 66s 490ms/step - loss: 0.0347 - accuracy: 0.9883 - val_loss: 0.0414 - val_accuracy: 0.9841
# Epoch 44/50
# 134/134 [==============================] - 64s 478ms/step - loss: 0.0521 - accuracy: 0.9817 - val_loss: 0.0383 - val_accuracy: 0.9869
# Epoch 45/50
# 134/134 [==============================] - 64s 474ms/step - loss: 0.0374 - accuracy: 0.9850 - val_loss: 0.0139 - val_accuracy: 0.9963
# Epoch 46/50
# 134/134 [==============================] - 65s 486ms/step - loss: 0.0305 - accuracy: 0.9864 - val_loss: 0.0118 - val_accuracy: 0.9963
# Epoch 47/50
# 134/134 [==============================] - 65s 484ms/step - loss: 0.0205 - accuracy: 0.9934 - val_loss: 0.0082 - val_accuracy: 0.9995
# Epoch 48/50
# 134/134 [==============================] - 66s 490ms/step - loss: 0.0217 - accuracy: 0.9930 - val_loss: 0.0057 - val_accuracy: 0.9995
# Epoch 49/50
# 134/134 [==============================] - 66s 488ms/step - loss: 0.0294 - accuracy: 0.9911 - val_loss: 0.0302 - val_accuracy: 0.9944
# Epoch 50/50
# 134/134 [==============================] - 64s 480ms/step - loss: 0.0130 - accuracy: 0.9967 - val_loss: 0.0181 - val_accuracy: 0.9935

# %%
score = model.evaluate_generator(test_generator)
print('Test loss : ', score[0])
print('Test accuracy : ', score[1])
# Out:
# /var/folders/zm/mpwd_g3j7vl1_27mwwvx0lm00000gn/T/ipykernel_35860/3196870277.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score = model.evaluate_generator(test_generator)
# Test loss :  0.01803870126605034
# Test accuracy :  0.99349445104599

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.save('final_model.h5')
